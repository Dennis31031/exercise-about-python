# %%
1+1
# Out:
# 2

# %%
4+55
# Out:
# 59

# %%
% matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(1)
# Out:
# 0.8414709848078965

# %%
plt.plot([1,1.2,1.4,1.6],[2,4,6,8])

# %%
a = [1,2,3,4]
b = [9,4,3,6]

# %%
plt.plot(a,b)

# %%
plt.scatter(a,b)

# %%
x = np.linspace(10,100,1000)
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()
# Out:
# <matplotlib.pyplot.xkcd.<locals>.dummy_ctx at 0x1c59f110128>

# %%
plt.plot(x,y)
